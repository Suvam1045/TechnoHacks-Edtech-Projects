# %% [markdown]
# ### Name- Suvam Sekhar Dash

# %% [markdown]
# ### Task-3

# %% [markdown]
# Data Visualization using Histogram

# %% [markdown]
# ### Importing Python Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %% [markdown]
# ### Importing the datset

# %%
df=pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\Datasets\Techno Hack\Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Getting the information about all columns in the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Checking for missing values in each column of the DataFrame.

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# There is no missing values in the DataFrame.

# %% [markdown]
# ### Checking for Outliers in the Columns Of DataFrame.

# %% [markdown]
# #### Checking Of Outliers in the"SepalLengthCm" Column Of DataFrame.

# %%
sns.boxplot(x=df["SepalLengthCm"],showfliers=True)
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %% [markdown]
# Note- There is no outlier present in the "SepallengthCm" column of DataFrame.

# %% [markdown]
# #### Checking Of Outliers in the"SepalWidthCm" Column Of DataFrame.

# %%
sns.boxplot(x=df["SepalWidthCm"],showfliers=True)
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %% [markdown]
# Note- There is some outlier present in the "SepallWidthCm" column of DataFrame.

# %% [markdown]
# #### Checking Of Outliers in the"PetalWidthCm" Column Of DataFrame.

# %%
sns.boxplot(x=df["PetalWidthCm"],showfliers=True)
# Out:
# <Axes: xlabel='PetalWidthCm'>

# %% [markdown]
# Note- There is no outlier present in the "PetalWidthCm" column of DataFrame.

# %% [markdown]
# #### Checking Of Outliers in the"PetalLengththCm" Column Of DataFrame.

# %%
sns.boxplot(x=df["PetalLengthCm"],showfliers=True)
# Out:
# <Axes: xlabel='PetalLengthCm'>

# %% [markdown]
# Note- There is no outlier present in the "PetalLengthCm" column of DataFrame.

# %% [markdown]
# #### Removing outlier present in the "SepallWidthCm" column of DataFrame.

# %%
def remove_outliers_IQR(df, SepalWidthCm, threshold=1.5):
    q1 = df["SepalWidthCm"].quantile(0.25)
    q3 = df["SepalWidthCm"].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - threshold * iqr
    upper_bound = q3 + threshold * iqr
    return df[(df["SepalWidthCm"] >= lower_bound) & (df["SepalWidthCm"] <= upper_bound)]

# %%
columns_to_check=["SepalWidthCm"]
for col in columns_to_check:
    df =remove_outliers_IQR(df, col)

# %%
sns.boxplot(x=df["SepalWidthCm"],showfliers=True)
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %% [markdown]
# Note-Now there is no outlier present in the "SepallWidthCm" column of DataFrame.

# %% [markdown]
# ## Data Visualisations

# %% [markdown]
# ### Plotting The Count Of Species Using Bar Chart

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Species',data=df, palette=['orange', 'lightblue', 'darkblue'])
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %% [markdown]
# ### Creating a Histogram for the column SepalLengthCm

# %%
df['SepalLengthCm'].hist(color='black')
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a Histogram for the column SepalWidthCm

# %%
df['SepalWidthCm'].hist(color='orange')
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a Histogram for the column PetalWidthCm

# %%
df['PetalWidthCm'].hist(color='green')
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a Histogram for the column PetalLengthCm

# %%
df['PetalLengthCm'].hist(color='lightblue')
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a bar chart of the mean of each column in the  DataFrame, grouped by the Species column

# %% [markdown]
# #### Creating a box plot to show relationship between Species and SepalLengthCm

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species',y='SepalLengthCm',data=df.sort_values('SepalLengthCm',ascending=False))
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# #### Creating a box plot to show relationship between Species and SepalWidthCm

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species', y='SepalWidthCm', data=df.sort_values('SepalWidthCm', ascending=False))
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %% [markdown]
# #### Creating a scatter plot to show relationship between SepalWidthCm and SepalLengthCm

# %%
df.plot(kind='scatter', x='SepalWidthCm', y='SepalLengthCm', color='violet')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %% [markdown]
# #### Creating a box plot to show relationship between Species and PetalLengthCm

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species',y='PetalLengthCm',data=df.sort_values('PetalLengthCm',ascending=False))
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# #### Creating a box plot to show relationship between Species and PetalWidthCm

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species',y='PetalWidthCm',data=df.sort_values('PetalWidthCm',ascending=False))
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# #### Creating a scatter plot to show relationship between PetalWidthCm and PetalLengthCm

# %%
df.plot(kind='scatter', x='PetalWidthCm', y='PetalLengthCm', color='red')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='PetalLengthCm'>

# %% [markdown]
# ### Creating a bar chart of the mean of each column in the  DataFrame, grouped by the Species column

# %%
df.groupby('Species').mean().plot(kind="bar", figsize=(15, 8))
plt.show()

# %% [markdown]
# ### Creating Pair Plot to show the relationship between variables in DataFrame.

# %%
sns.pairplot(df,hue='Species',height=3)

# %% [markdown]
# ### Creating correlation matrix, which shows the correlation between each pair of columns in the DataFrame

# %%
df.corr(numeric_only=True)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.718722     -0.384320       0.880016
# SepalLengthCm  0.718722       1.000000     -0.113977       0.879374
# SepalWidthCm  -0.384320      -0.113977      1.000000      -0.397123
# PetalLengthCm  0.880016       0.879374     -0.397123       1.000000
# PetalWidthCm   0.898193       0.822577     -0.329782       0.961755
#
#                PetalWidthCm
# Id                 0.898193
# SepalLengthCm      0.822577
# SepalWidthCm      -0.329782
# PetalLengthCm      0.961755
# PetalWidthCm       1.000000

# %% [markdown]
# ### Displaying the correlation using Heatmap

# %%
corr=df.corr(numeric_only=True)
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot=True, ax=ax, cmap='cividis')
# Out:
# <Axes: >
