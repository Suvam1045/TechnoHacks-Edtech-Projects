# %% [markdown]
# '
# ### Name- Suvam Sekhar Dash

# %% [markdown]
# ### Task 1

# %% [markdown]
# Cleaning the Titanic dataset by removing missing values and outliers.

# %% [markdown]
# ### Importing The Python Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %% [markdown]
# ### Importing The Dataset

# %%
data=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Datasets\Techno Hack\Titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Geting The Top 20  Rows Of The DataFrame

# %%
top_data= data.head(20)
top_data
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# ...

# %% [markdown]
# ### Geting The Top 20  Rows From Bottom Of The DataFrame

# %%
bottom_data= data.tail(20)
bottom_data
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %% [markdown]
# ### Getting the data types of all columns in the DataFrame.

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Statistical Details Of Data Frame

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Counting the number of missing values in each column of the DataFrame.

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %% [markdown]
# ### Calculating the percentage of missing values in DataFrame

# %%
missing_percentage = (data.isnull().sum() / len(data)) * 100
print(missing_percentage)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# ### Visualizing the missing data

# %%
#visualize the missing data
sns.heatmap(data.isnull(), cmap='viridis', cbar=False)
plt.show()

# %% [markdown]
# ### Calculating the mean of the Age column in the DataFrame

# %%
int(data["Age"].mean())
# Out:
# 29

# %% [markdown]
# ### Replacing the missing values with Mean Values in Age Column

# %%
data["Age"]=data["Age"].fillna(np.mean(data["Age"]))

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Calculating the mean of the Fare column in the DataFrame

# %%
int(data["Fare"].mean())
# Out:
# 32

# %% [markdown]
# ### Replacing the missing values with Mean Values in Fare Column

# %%
data["Fare"]=data["Fare"].fillna(np.mean(data["Fare"]))

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Counting the number of unique values in the Cabin column of the DataFrame

# %%
data["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %% [markdown]
# ### Calculating the mode of the Cabin column in the DataFrame

# %%
data["Cabin"].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %% [markdown]
# ### Replacing the missing values with Mode Values in Cabin Column

# %%
data["Cabin"].fillna(data["Cabin"].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### Visualisation Of Outliers In Fare Column Of DataFrame

# %%
sns.boxplot(x=data["Fare"],showfliers=True)
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# ### Visualisation Of Outliers In Age Column Of DataFrame

# %%
sns.boxplot(x=data["Age"],showfliers=True)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ### Removing the outliers for fare column

# %%
def remove_outliers_IQR(data, Fare, threshold=1.5):
    q1 = data["Fare"].quantile(0.25)
    q3 = data["Fare"].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - threshold * iqr
    upper_bound = q3 + threshold * iqr
    return data[(data["Fare"] >= lower_bound) & (data['Fare'] <= upper_bound)]

# %%
columns_to_check = ['Fare']
for col in columns_to_check:
    data1 = remove_outliers_IQR(data, col)

# %% [markdown]
# #### Comparsion between with and without outliers in fare column for better understanding

# %%
#comparsion between with and without outliers in fare column for better understanding
plt.figure(figsize=(10, 6))
plt.boxplot([data['Fare'], data1['Fare']], labels=['With Outliers', 'Without Outliers'])
plt.title('Comparison of Fare with and without outliers')
plt.xlabel('Data with and without outliers')
plt.ylabel('Fare Values')
plt.show()

# %% [markdown]
# ### Removing the outliers for Age column

# %%
def remove_outliers_IQR(data1, Fare, threshold=1.5):
    q1 = data1["Age"].quantile(0.25)
    q3 = data1["Age"].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - threshold * iqr
    upper_bound = q3 + threshold * iqr
    return data1[(data1["Age"] >= lower_bound) & (data1['Age'] <= upper_bound)]

# %%
columns_to_check = ['Age']
for col in columns_to_check:
    data2 = remove_outliers_IQR(data1, col)

# %% [markdown]
# Here data2 is new dataframe with no missing values and without outliers in fare & age column.

# %% [markdown]
# #### Comparsion between with and without outliers in age column for better understanding

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([data1['Age'],data2['Age']], labels=['With Outliers', 'Without Outliers'])
plt.title('Comparison of Age with and without outliers')
plt.xlabel('Data with and without outliers')
plt.ylabel('Age Values')
plt.show()

# %% [markdown]
#  Data Is Cleaned And Outliers Has Been Removed.

# %% [markdown]
# ### Saving the cleaned dataset

# %%
data2.to_csv('titanic cleaned data.csv')
